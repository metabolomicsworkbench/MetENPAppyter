# %%
import rpy2
import rpy2.robjects as robjects
import rpy2.robjects.packages as rpackages

from rpy2.robjects import numpy2ri, pandas2ri
#numpy2ri.activate()
#pandas2ri.activate()

#numpy2ri.deactivate()
#pandas2ri.deactivate()

print(rpy2.__version__)

robjects.r('''

library(MetENP)

''')

#bring this variable into R
#r['study_id'] = {{ study_id }}
#r('head(study_id)')
# Out:
# 3.4.2
# <rpy2.robjects.vectors.StrVector object at 0x7ffe61a0bf00> [RTYPES.STRSXP]
# R classes: ('character',)
# ['MetENP', 'tools', 'stats', 'graphics', ..., 'utils', 'datasets', 'methods', 'base']

# %%
data_1 = robjects.r['getmwstudies']('ST000915', 
    'data'
)

# %%
#TODO: outputs are not the same type as the original vignette
robjects.r['head'](data_1)
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe5f613800> [RTYPES.VECSXP]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [ListSexpV..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe5f613800> [RTYPES.VECSXP]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [ListSexpV..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe5f613800> [RTYPES.VECSXP]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [ListSexpV..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe5f613800> [RTYPES.VECSXP]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [ListSexpV..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe5f613800> [RTYPES.VECSXP]
# R classes: ('tbl_df', 'tbl', 'data.frame')
# [ListSexpV..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# ...
#   NASH001: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe61a33a40> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, '0.24..., '0.10..., NA_character_, '0.01..., '0.03...]
#   NASH002: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe61a3b740> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, '0.25..., '0.05..., '0.00..., '0.01..., '0.00...]
#   NASH003: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe61a3b440> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, '0.03..., '0.08..., NA_character_, '0.00..., '0.00...]
#   NASH004: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe497ab140> [RTYPES.STRSXP]
# R classes: ('character',)
# [NA_character_, '0.05..., '0.10..., NA_character_, '0.01..., '0.01...]

# %%
robjects.r['is.data.frame'](data_1)
#print(type(data_1))
# Out:
# <rpy2.robjects.vectors.BoolVector object at 0x7ffe497ac800> [RTYPES.LGLSXP]
# R classes: ('logical',)
# [       1]

# %%
metadata = robjects.r['getmwstudies']('ST000915', 
    'factors'
)

# %%
robjects.r['head'](metadata)
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe497b52c0> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [ListSex..., ListSex..., ListSex..., ListSex..., StrSexp...]
#   study_id: <class 'rpy2.rinterface.ListSexpVector'>
#   <rpy2.rinterface.ListSexpVector object at 0x7ffe497b5140> [RTYPES.VECSXP]
#   local_sample_id: <class 'rpy2.rinterface.ListSexpVector'>
#   <rpy2.rinterface.ListSexpVector object at 0x7ffe497b5280> [RTYPES.VECSXP]
#   subject_type: <class 'rpy2.rinterface.ListSexpVector'>
#   <rpy2.rinterface.ListSexpVector object at 0x7ffe497b5780> [RTYPES.VECSXP]
#   factors: <class 'rpy2.rinterface.ListSexpVector'>
#   <rpy2.rinterface.ListSexpVector object at 0x7ffe497b5900> [RTYPES.VECSXP]
#   Diagnosis: <class 'rpy2.rinterface_lib.sexp.StrSexpVector'>
#   <rpy2.rinterface_lib.sexp.StrSexpVector object at 0x7ffe497b5a80> [RTYPES.STRSXP]

# %% [markdown]
# Find the factors you would want to compare
# Multiple factors (independent variables) are formatted in multiple columns but you can get information on all the factors by "factors" column, such as 'TreatmentGroup:Prednisolone', this indicates column name 'TreatmentGroup' with factor Prednisolone. For t-test use the factors in the same column. For comparing multipe independent variables use anova by anova_ana function.

# %% [markdown]
# ### Associate metabolomics data to the refmet class

# %%
refmet_class = robjects.r['convert_refmet'](data_1)

# %%
robjects.r['head'](refmet_class)
# Out:
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe497bb200> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [StrSexpVe..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
#   metabolite_name: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe497bb380> [RTYPES.STRSXP]
# R classes: ('character',)
# ['1,2-..., '1,2-..., '1,2-..., '1,2-..., '1,2-..., '1,2-...]
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe497bb200> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [StrSexpVe..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe497bb200> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [StrSexpVe..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# <rpy2.robjects.vectors.DataFrame object at 0x7ffe497bb200> [RTYPES.VECSXP]
# R classes: ('data.frame',)
# [StrSexpVe..., ListSexpV..., ListSexpV..., ListSexpV..., ..., StrSexpVe..., StrSexpVe..., StrSexpVe..., StrSexpVe...]
# ...
#   NASH001: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe497bbc80> [RTYPES.STRSXP]
# R classes: ('character',)
# ['C33H..., 'C33H..., 'C35H..., 'C35H..., 'C35H..., 'C35H...]
#   NASH002: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe497bb500> [RTYPES.STRSXP]
# R classes: ('character',)
# ['Glyc..., 'Glyc..., 'Glyc..., 'Glyc..., 'Glyc..., 'Glyc...]
#   NASH003: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe497bd2c0> [RTYPES.STRSXP]
# R classes: ('character',)
# ['Dira..., 'Dira..., 'Dira..., 'Dira..., 'Dira..., 'Dira...]
#   NASH004: <class 'rpy2.robjects.vectors.StrVector'>
#   <rpy2.robjects.vectors.StrVector object at 0x7ffe497bd540> [RTYPES.STRSXP]
# R classes: ('character',)
# ['DAG', 'DAG', 'DAG', 'DAG', 'DAG', 'DAG']

# %%
#bring this variable into R
r.robjects['data_1'] = 
r.robjects('''
unique($analysis_summary)
''')
# Out:
#   File "<ipython-input-9-342bab5a2c3b>", line 2
#     r.robjects['data_1'] =
#                            ^
# SyntaxError: invalid syntax

# %%
#unique(data$analysis_summary)

# %% [markdown]
# ### Find significant metabolites, run significance of all the analysis summary together. The analysis summary/modes you got in the previous section

# %% [markdown]
# There is a normalization step which takes into account missing values, and this can be achieved via three methods:
#
# 1) half_of_min: where the NAs are replaced by half of min values in the data
#
# 2) remove_NAs: where Cols with NAs values are removed
#
# 3) 50percent: where cols with more than 50% NAs values are removed
#
# half_of_min is ideal when you wish to see which metabolites were present in either group. Very high fold change would mean it was present in either group.

# %%
#need to change to float
robjects.r['print']('0.05')

# %%
thres_log2foldchange = '0.5'
thres_log2foldchange = float(thres_log2foldchange)
thres_log2foldchange

# %%
thres_log2foldchange_countclass = '0.5'
thres_log2foldchange_countclass = float(thres_log2foldchange_countclass)
thres_log2foldchange_countclass

# %%
sigmets = 3
sigmets

# %%
x_size_heat = 8
x_size_heat

# %%
y_size_heat = 6
y_size_heat

# %%
x_size_dot = 8
x_size_dot

# %%
y_size_dot = 6
y_size_dot
