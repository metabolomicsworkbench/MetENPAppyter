# %%
import rpy2
print(rpy2.__version__)

import rpy2.robjects as robjects

import rpy2.robjects.packages as rpackages

pi = robjects.r['pi']
pi[0]

robjects.r('''

library(MetENP)''')
# Out:
# 3.4.2
# <rpy2.robjects.vectors.StrVector object at 0x7f8a1ffd5f00> [RTYPES.STRSXP]
# R classes: ('character',)
# ['MetENP', 'tools', 'stats', 'graphics', ..., 'utils', 'datasets', 'methods', 'base']

# %%
data11 = robjects.r['getmwstudies']('ST000915', 
    'factors'
)
print(data11[0:6])
# Out:
# [[1]]
# [[1]]$`1`
# [1] "ST000915"
#
# [[1]]$`2`
# [1] "ST000915"
#
# [[1]]$`3`
# [1] "ST000915"
#
# [[1]]$`4`
# [1] "ST000915"
#
# [[1]]$`5`
# [1] "ST000915"
#
# [[1]]$`6`
# [1] "ST000915"
#
# [[1]]$`7`
# [1] "ST000915"
#
# [[1]]$`8`
# [1] "ST000915"
#
# [[1]]$`9`
# [1] "ST000915"
#
# [[1]]$`10`
# [1] "ST000915"
#
# [[1]]$`11`
# [1] "ST000915"
#
# [[1]]$`12`
# [1] "ST000915"
#
# [[1]]$`13`
# [1] "ST000915"
#
# [[1]]$`14`
# [1] "ST000915"
#
# [[1]]$`15`
# [1] "ST000915"
#
# [[1]]$`16`
# [1] "ST000915"
#
# [[1]]$`17`
# [1] "ST000915"
#
# [[1]]$`18`
# [1] "ST000915"
#
# [[1]]$`19`
# [1] "ST000915"
#
# [[1]]$`20`
# [1] "ST000915"
#
# [[1]]$`21`
# [1] "ST000915"
#
# [[1]]$`22`
# [1] "ST000915"
#
# [[1]]$`23`
# [1] "ST000915"
#
# [[1]]$`24`
# [1] "ST000915"
#
# [[1]]$`25`
# [1] "ST000915"
#
# [[1]]$`26`
# [1] "ST000915"
#
# [[1]]$`27`
# [1] "ST000915"
#
# [[1]]$`28`
# [1] "ST000915"
#
# [[1]]$`29`
# [1] "ST000915"
#
# [[1]]$`30`
# [1] "ST000915"
#
# [[1]]$`31`
# [1] "ST000915"
#
# [[1]]$`32`
# [1] "ST000915"
#
# [[1]]$`33`
# [1] "ST000915"
#
# [[1]]$`34`
# [1] "ST000915"
#
# [[1]]$`35`
# [1] "ST000915"
#
# [[1]]$`36`
# [1] "ST000915"
#
# [[1]]$`37`
# [1] "ST000915"
#
# [[1]]$`38`
# [1] "ST000915"
#
# [[1]]$`39`
# [1] "ST000915"
#
# [[1]]$`40`
# [1] "ST000915"
#
# [[1]]$`41`
# [1] "ST000915"
#
# [[1]]$`42`
# [1] "ST000915"
#
# [[1]]$`43`
# [1] "ST000915"
#
# [[1]]$`44`
# [1] "ST000915"
#
# [[1]]$`45`
# [1] "ST000915"
#
# [[1]]$`46`
# [1] "ST000915"
#
# [[1]]$`47`
# [1] "ST000915"
#
# [[1]]$`48`
# [1] "ST000915"
#
# [[1]]$`49`
# [1] "ST000915"
#
# [[1]]$`50`
# [1] "ST000915"
#
# [[1]]$`51`
# [1] "ST000915"
#
# [[1]]$`52`
# [1] "ST000915"
#
# [[1]]$`53`
# [1] "ST000915"
#
# [[1]]$`54`
# [1] "ST000915"
#
# [[1]]$`55`
# [1] "ST000915"
#
# [[1]]$`56`
# [1] "ST000915"
#
# [[1]]$`57`
# [1] "ST000915"
#
# [[1]]$`58`
# [1] "ST000915"
#
# [[1]]$`59`
# [1] "ST000915"
#
# [[1]]$`60`
# [1] "ST000915"
#
# [[1]]$`61`
# [1] "ST000915"
#
# [[1]]$`62`
# [1] "ST000915"
#
# [[1]]$`63`
# [1] "ST000915"
#
# [[1]]$`64`
# [1] "ST000915"
#
# [[1]]$`65`
# [1] "ST000915"
#
# [[1]]$`66`
# [1] "ST000915"
#
# [[1]]$`67`
# [1] "ST000915"
#
# [[1]]$`68`
# [1] "ST000915"
#
# [[1]]$`69`
# [1] "ST000915"
#
# [[1]]$`70`
# [1] "ST000915"
#
# [[1]]$`71`
# [1] "ST000915"
#
# [[1]]$`72`
# [1] "ST000915"
#
# [[1]]$`73`
# [1] "ST000915"
#
# [[1]]$`74`
# [1] "ST000915"
#
# [[1]]$`75`
# [1] "ST000915"
#
# [[1]]$`76`
# [1] "ST000915"
#
# [[1]]$`77`
# [1] "ST000915"
#
# [[1]]$`78`
# [1] "ST000915"
#
# [[1]]$`79`
# [1] "ST000915"
#
# [[1]]$`80`
# [1] "ST000915"
#
# [[1]]$`81`
# [1] "ST000915"
#
# [[1]]$`82`
# [1] "ST000915"
#
# [[1]]$`83`
# [1] "ST000915"
#
# [[1]]$`84`
# [1] "ST000915"
#
# [[1]]$`85`
# [1] "ST000915"
#
# [[1]]$`86`
# [1] "ST000915"
#
# [[1]]$`87`
# [1] "ST000915"
#
# [[1]]$`88`
# [1] "ST000915"
#
#
# [[2]]
# [[2]]$`1`
# [1] "NASH005"
#
# [[2]]$`2`
# [1] "NASH007"
#
# [[2]]$`3`
# [1] "NASH009"
#
# [[2]]$`4`
# [1] "NASH013"
#
# [[2]]$`5`
# [1] "NASH016"
#
# [[2]]$`6`
# [1] "NASH022"
#
# [[2]]$`7`
# [1] "NASH026"
#
# [[2]]$`8`
# [1] "NASH027"
#
# [[2]]$`9`
# [1] "NASH028"
#
# [[2]]$`10`
# [1] "NASH029"
#
# [[2]]$`11`
# [1] "NASH040"
#
# [[2]]$`12`
# [1] "NASH047"
#
# [[2]]$`13`
# [1] "NASH048"
#
# [[2]]$`14`
# [1] "NASH049"
#
# [[2]]$`15`
# [1] "NASH052"
#
# [[2]]$`16`
# [1] "NASH055"
#
# [[2]]$`17`
# [1] "NASH064"
#
# [[2]]$`18`
# [1] "NASH065"
#
# [[2]]$`19`
# [1] "NASH068"
#
# [[2]]$`20`
# [1] "NASH069"
#
# [[2]]$`21`
# [1] "NASH010"
#
# [[2]]$`22`
# [1] "NASH012"
#
# [[2]]$`23`
# [1] "NASH015"
#
# [[2]]$`24`
# [1] "NASH018"
#
# [[2]]$`25`
# [1] "NASH019"
#
# [[2]]$`26`
# [1] "NASH021"
#
# [[2]]$`27`
# [1] "NASH030"
#
# [[2]]$`28`
# [1] "NASH031"
#
# [[2]]$`29`
# [1] "NASH035"
#
# [[2]]$`30`
# [1] "NASH037"
#
# [[2]]$`31`
# [1] "NASH038"
#
# [[2]]$`32`
# [1] "NASH039"
#
# [[2]]$`33`
# [1] "NASH044"
#
# [[2]]$`34`
# [1] "NASH057"
#
# [[2]]$`35`
# [1] "NASH072"
#
# [[2]]$`36`
# [1] "NASH074"
#
# [[2]]$`37`
# [1] "NASH084"
#
# [[2]]$`38`
# [1] "NASH087"
#
# [[2]]$`39`
# [1] "NASH088"
#
# [[2]]$`40`
# [1] "NASH090"
#
# [[2]]$`41`
# [1] "NASH003"
#
# [[2]]$`42`
# [1] "NASH004"
#
# [[2]]$`43`
# [1] "NASH006"
#
# [[2]]$`44`
# [1] "NASH011"
#
# [[2]]$`45`
# [1] "NASH014"
#
# [[2]]$`46`
# [1] "NASH017"
#
# [[2]]$`47`
# [1] "NASH020"
#
# [[2]]$`48`
# [1] "NASH024"
#
# [[2]]$`49`
# [1] "NASH034"
#
# [[2]]$`50`
# [1] "NASH036"
#
# [[2]]$`51`
# [1] "NASH041"
#
# [[2]]$`52`
# [1] "NASH042"
#
# [[2]]$`53`
# [1] "NASH043"
#
# [[2]]$`54`
# [1] "NASH045"
#
# [[2]]$`55`
# [1] "NASH046"
#
# [[2]]$`56`
# [1] "NASH050"
#
# [[2]]$`57`
# [1] "NASH051"
#
# [[2]]$`58`
# [1] "NASH053"
#
# [[2]]$`59`
# [1] "NASH054"
#
# [[2]]$`60`
# [1] "NASH060"
#
# [[2]]$`61`
# [1] "NASH066"
#
# [[2]]$`62`
# [1] "NASH067"
#
# [[2]]$`63`
# [1] "NASH070"
#
# [[2]]$`64`
# [1] "NASH077"
#
# [[2]]$`65`
# [1] "NASH078"
#
# [[2]]$`66`
# [1] "NASH080"
#
# [[2]]$`67`
# [1] "NASH082"
#
# [[2]]$`68`
# [1] "NASH085"
#
# [[2]]$`69`
# [1] "NASH086"
#
# [[2]]$`70`
# [1] "NASH089"
#
# [[2]]$`71`
# [1] "NASH091"
#
# [[2]]$`72`
# [1] "NASH001"
#
# [[2]]$`73`
# [1] "NASH002"
#
# [[2]]$`74`
# [1] "NASH023"
#
# [[2]]$`75`
# [1] "NASH032"
#
# [[2]]$`76`
# [1] "NASH033"
#
# [[2]]$`77`
# [1] "NASH056"
#
# [[2]]$`78`
# [1] "NASH058"
#
# [[2]]$`79`
# [1] "NASH059"
#
# [[2]]$`80`
# [1] "NASH061"
#
# [[2]]$`81`
# [1] "NASH062"
#
# [[2]]$`82`
# [1] "NASH071"
#
# [[2]]$`83`
# [1] "NASH073"
#
# [[2]]$`84`
# [1] "NASH075"
#
# [[2]]$`85`
# [1] "NASH076"
#
# [[2]]$`86`
# [1] "NASH079"
#
# [[2]]$`87`
# [1] "NASH081"
#
# [[2]]$`88`
# [1] "NASH083"
#
#
# [[3]]
# [[3]]$`1`
# [1] "Human clinical study"
#
# [[3]]$`2`
# [1] "Human clinical study"
#
# [[3]]$`3`
# [1] "Human clinical study"
#
# [[3]]$`4`
# [1] "Human clinical study"
#
# [[3]]$`5`
# [1] "Human clinical study"
#
# [[3]]$`6`
# [1] "Human clinical study"
#
# [[3]]$`7`
# [1] "Human clinical study"
#
# [[3]]$`8`
# [1] "Human clinical study"
#
# [[3]]$`9`
# [1] "Human clinical study"
#
# [[3]]$`10`
# [1] "Human clinical study"
#
# [[3]]$`11`
# [1] "Human clinical study"
#
# [[3]]$`12`
# [1] "Human clinical study"
#
# [[3]]$`13`
# [1] "Human clinical study"
#
# [[3]]$`14`
# [1] "Human clinical study"
#
# [[3]]$`15`
# [1] "Human clinical study"
#
# [[3]]$`16`
# [1] "Human clinical study"
#
# [[3]]$`17`
# [1] "Human clinical study"
#
# [[3]]$`18`
# [1] "Human clinical study"
#
# [[3]]$`19`
# [1] "Human clinical study"
#
# [[3]]$`20`
# [1] "Human clinical study"
#
# [[3]]$`21`
# [1] "Human clinical study"
#
# [[3]]$`22`
# [1] "Human clinical study"
#
# [[3]]$`23`
# [1] "Human clinical study"
#
# [[3]]$`24`
# [1] "Human clinical study"
#
# [[3]]$`25`
# [1] "Human clinical study"
#
# [[3]]$`26`
# [1] "Human clinical study"
#
# [[3]]$`27`
# [1] "Human clinical study"
#
# [[3]]$`28`
# [1] "Human clinical study"
#
# [[3]]$`29`
# [1] "Human clinical study"
#
# [[3]]$`30`
# [1] "Human clinical study"
#
# [[3]]$`31`
# [1] "Human clinical study"
#
# [[3]]$`32`
# [1] "Human clinical study"
#
# [[3]]$`33`
# [1] "Human clinical study"
#
# [[3]]$`34`
# [1] "Human clinical study"
#
# [[3]]$`35`
# [1] "Human clinical study"
#
# [[3]]$`36`
# [1] "Human clinical study"
#
# [[3]]$`37`
# [1] "Human clinical study"
#
# [[3]]$`38`
# [1] "Human clinical study"
#
# [[3]]$`39`
# [1] "Human clinical study"
#
# [[3]]$`40`
# [1] "Human clinical study"
#
# [[3]]$`41`
# [1] "Human clinical study"
#
# [[3]]$`42`
# [1] "Human clinical study"
#
# [[3]]$`43`
# [1] "Human clinical study"
#
# [[3]]$`44`
# [1] "Human clinical study"
#
# [[3]]$`45`
# [1] "Human clinical study"
#
# [[3]]$`46`
# [1] "Human clinical study"
#
# [[3]]$`47`
# [1] "Human clinical study"
#
# [[3]]$`48`
# [1] "Human clinical study"
#
# [[3]]$`49`
# [1] "Human clinical study"
#
# [[3]]$`50`
# [1] "Human clinical study"
#
# [[3]]$`51`
# [1] "Human clinical study"
#
# [[3]]$`52`
# [1] "Human clinical study"
#
# [[3]]$`53`
# [1] "Human clinical study"
#
# [[3]]$`54`
# [1] "Human clinical study"
#
# [[3]]$`55`
# [1] "Human clinical study"
#
# [[3]]$`56`
# [1] "Human clinical study"
#
# [[3]]$`57`
# [1] "Human clinical study"
#
# [[3]]$`58`
# [1] "Human clinical study"
#
# [[3]]$`59`
# [1] "Human clinical study"
#
# [[3]]$`60`
# [1] "Human clinical study"
#
# [[3]]$`61`
# [1] "Human clinical study"
#
# [[3]]$`62`
# [1] "Human clinical study"
#
# [[3]]$`63`
# [1] "Human clinical study"
#
# [[3]]$`64`
# [1] "Human clinical study"
#
# [[3]]$`65`
# [1] "Human clinical study"
#
# [[3]]$`66`
# [1] "Human clinical study"
#
# [[3]]$`67`
# [1] "Human clinical study"
#
# [[3]]$`68`
# [1] "Human clinical study"
#
# [[3]]$`69`
# [1] "Human clinical study"
#
# [[3]]$`70`
# [1] "Human clinical study"
#
# [[3]]$`71`
# [1] "Human clinical study"
#
# [[3]]$`72`
# [1] "Human clinical study"
#
# [[3]]$`73`
# [1] "Human clinical study"
#
# [[3]]$`74`
# [1] "Human clinical study"
#
# [[3]]$`75`
# [1] "Human clinical study"
#
# [[3]]$`76`
# [1] "Human clinical study"
#
# [[3]]$`77`
# [1] "Human clinical study"
#
# [[3]]$`78`
# [1] "Human clinical study"
#
# [[3]]$`79`
# [1] "Human clinical study"
#
# [[3]]$`80`
# [1] "Human clinical study"
#
# [[3]]$`81`
# [1] "Human clinical study"
#
# [[3]]$`82`
# [1] "Human clinical study"
#
# [[3]]$`83`
# [1] "Human clinical study"
#
# [[3]]$`84`
# [1] "Human clinical study"
#
# [[3]]$`85`
# [1] "Human clinical study"
#
# [[3]]$`86`
# [1] "Human clinical study"
#
# [[3]]$`87`
# [1] "Human clinical study"
#
# [[3]]$`88`
# [1] "Human clinical study"
#
#
# [[4]]
# [[4]]$`1`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`2`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`3`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`4`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`5`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`6`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`7`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`8`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`9`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`10`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`11`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`12`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`13`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`14`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`15`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`16`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`17`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`18`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`19`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`20`
# [1] "Diagnosis:Cirrhosis"
#
# [[4]]$`21`
# [1] "Diagnosis:NASH"
#
# [[4]]$`22`
# [1] "Diagnosis:NASH"
#
# [[4]]$`23`
# [1] "Diagnosis:NASH"
#
# [[4]]$`24`
# [1] "Diagnosis:NASH"
#
# [[4]]$`25`
# [1] "Diagnosis:NASH"
#
# [[4]]$`26`
# [1] "Diagnosis:NASH"
#
# [[4]]$`27`
# [1] "Diagnosis:NASH"
#
# [[4]]$`28`
# [1] "Diagnosis:NASH"
#
# [[4]]$`29`
# [1] "Diagnosis:NASH"
#
# [[4]]$`30`
# [1] "Diagnosis:NASH"
#
# [[4]]$`31`
# [1] "Diagnosis:NASH"
#
# [[4]]$`32`
# [1] "Diagnosis:NASH"
#
# [[4]]$`33`
# [1] "Diagnosis:NASH"
#
# [[4]]$`34`
# [1] "Diagnosis:NASH"
#
# [[4]]$`35`
# [1] "Diagnosis:NASH"
#
# [[4]]$`36`
# [1] "Diagnosis:NASH"
#
# [[4]]$`37`
# [1] "Diagnosis:NASH"
#
# [[4]]$`38`
# [1] "Diagnosis:NASH"
#
# [[4]]$`39`
# [1] "Diagnosis:NASH"
#
# [[4]]$`40`
# [1] "Diagnosis:NASH"
#
# [[4]]$`41`
# [1] "Diagnosis:Normal"
#
# [[4]]$`42`
# [1] "Diagnosis:Normal"
#
# [[4]]$`43`
# [1] "Diagnosis:Normal"
#
# [[4]]$`44`
# [1] "Diagnosis:Normal"
#
# [[4]]$`45`
# [1] "Diagnosis:Normal"
#
# [[4]]$`46`
# [1] "Diagnosis:Normal"
#
# [[4]]$`47`
# [1] "Diagnosis:Normal"
#
# [[4]]$`48`
# [1] "Diagnosis:Normal"
#
# [[4]]$`49`
# [1] "Diagnosis:Normal"
#
# [[4]]$`50`
# [1] "Diagnosis:Normal"
#
# [[4]]$`51`
# [1] "Diagnosis:Normal"
#
# [[4]]$`52`
# [1] "Diagnosis:Normal"
#
# [[4]]$`53`
# [1] "Diagnosis:Normal"
#
# [[4]]$`54`
# [1] "Diagnosis:Normal"
#
# [[4]]$`55`
# [1] "Diagnosis:Normal"
#
# [[4]]$`56`
# [1] "Diagnosis:Normal"
#
# [[4]]$`57`
# [1] "Diagnosis:Normal"
#
# [[4]]$`58`
# [1] "Diagnosis:Normal"
#
# [[4]]$`59`
# [1] "Diagnosis:Normal"
#
# [[4]]$`60`
# [1] "Diagnosis:Normal"
#
# [[4]]$`61`
# [1] "Diagnosis:Normal"
#
# [[4]]$`62`
# [1] "Diagnosis:Normal"
#
# [[4]]$`63`
# [1] "Diagnosis:Normal"
#
# [[4]]$`64`
# [1] "Diagnosis:Normal"
#
# [[4]]$`65`
# [1] "Diagnosis:Normal"
#
# [[4]]$`66`
# [1] "Diagnosis:Normal"
#
# [[4]]$`67`
# [1] "Diagnosis:Normal"
#
# [[4]]$`68`
# [1] "Diagnosis:Normal"
#
# [[4]]$`69`
# [1] "Diagnosis:Normal"
#
# [[4]]$`70`
# [1] "Diagnosis:Normal"
#
# [[4]]$`71`
# [1] "Diagnosis:Normal"
#
# [[4]]$`72`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`73`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`74`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`75`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`76`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`77`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`78`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`79`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`80`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`81`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`82`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`83`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`84`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`85`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`86`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`87`
# [1] "Diagnosis:Steatosis"
#
# [[4]]$`88`
# [1] "Diagnosis:Steatosis"
#
#
# [[5]]
#  [1] "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis"
#  [7] "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis"
# [13] "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis" "Cirrhosis"
# [19] "Cirrhosis" "Cirrhosis" "NASH"      "NASH"      "NASH"      "NASH"
# [25] "NASH"      "NASH"      "NASH"      "NASH"      "NASH"      "NASH"
# [31] "NASH"      "NASH"      "NASH"      "NASH"      "NASH"      "NASH"
# [37] "NASH"      "NASH"      "NASH"      "NASH"      "Normal"    "Normal"
# [43] "Normal"    "Normal"    "Normal"    "Normal"    "Normal"    "Normal"
# [49] "Normal"    "Normal"    "Normal"    "Normal"    "Normal"    "Normal"
# [55] "Normal"    "Normal"    "Normal"    "Normal"    "Normal"    "Normal"
# [61] "Normal"    "Normal"    "Normal"    "Normal"    "Normal"    "Normal"
# [67] "Normal"    "Normal"    "Normal"    "Normal"    "Normal"    "Steatosis"
# [73] "Steatosis" "Steatosis" "Steatosis" "Steatosis" "Steatosis" "Steatosis"
# [79] "Steatosis" "Steatosis" "Steatosis" "Steatosis" "Steatosis" "Steatosis"
# [85] "Steatosis" "Steatosis" "Steatosis" "Steatosis"

# %%
normtype = ['50percent']
normtype
# Out:
# ['50percent']

# %%
pthres = '0.05'
pthres = float(pthres)
pthres
# Out:
# 0.05

# %%
thres_log2foldchange = '0.5'
thres_log2foldchange = float(thres_log2foldchange)
thres_log2foldchange
# Out:
# 0.5

# %%
thres_log2foldchange_countclass = '0.5'
thres_log2foldchange_countclass = float(thres_log2foldchange_countclass)
thres_log2foldchange_countclass
# Out:
# 0.5

# %%
sigmets = 3
sigmets
# Out:
# 3

# %%
x_size_heat = 8
x_size_heat
# Out:
# 8

# %%
y_size_heat = 6
y_size_heat
# Out:
# 6

# %%
x_size_dot = 8
x_size_dot
# Out:
# 8

# %%
y_size_dot = 6
y_size_dot
# Out:
# 6
